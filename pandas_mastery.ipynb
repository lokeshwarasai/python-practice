# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshwarasai/python-practice/blob/main/pandas_mastery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
raw_data={"message":["hi","hello","how r u?"],
          "label":["good","fine","bad"]
          }
df=pd.DataFrame(raw_data)
print(df)
#simple pandas data frame
# Out:
#     message label
# 0        hi  good
# 1     hello  fine
# 2  how r u?   bad

# %%
import pandas as pd
import numpy as np

data = np.array(['L','O','K','E','S','H'])
s = pd.Series(data)
print("Pandas Series:")
print(s)
# pandas series
# Out:
# Pandas Series:
# 0    L
# 1    O
# 2    K
# 3    E
# 4    S
# 5    H
# dtype: object

# %%
import pandas as pd

df = pd.DataFrame()
print(df)
lst = ['HI','HELLO','THIS','IS','LOKESH']

df = pd.DataFrame(lst)
print(df)
#PANDAS DATA FRAME
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0      HI
# 1   HELLO
# 2    THIS
# 3      IS
# 4  LOKESH

# %%
import pandas as pd
import io


df = pd.read_csv('data-.csv')
print(df.head())
# Out:
#     name  age     city category  sales  a   b
# 0   John   25    Delhi        A    200  5  10
# 1   Riya   22   Mumbai        B    120  2   3
# 2   Aman   30     Pune        A    250  7   8
# 3   Neha   27  Kolkata        C    300  4   6
# 4  Arjun   35   Jaipur        B    200  1   9
